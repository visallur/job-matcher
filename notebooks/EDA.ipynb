# %%
import pandas as pd

jobs = pd.read_csv("../data/jobs.csv")
resumes = pd.read_csv("../data/resumes.csv")

jobs.head(), resumes.head()
# Out:
# Running cells with '.venv (Python 3.14.0)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'x:/DATA641/job-matcher/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'
